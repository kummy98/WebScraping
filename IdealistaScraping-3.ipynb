# %% [markdown]
# ## scraping of Idealista.it

# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import json

# %% [markdown]
# first of all we need some boring stuff like the headers
#
#
# headers are used to avoid being blocked when doing **data scrapring**

# %%
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) '
                  'Chrome/100.0.4896.75 Safari/537.36',
    'Accept-Language': 'it-IT,it;q=0.9,en-US;q=0.8,en;q=0.7',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,'
              'application/signed-exchange;v=b3;q=0.9',
    'sec-ch-ua': '"Not A;Brand";v="99", "Chromium";v="100", "Google Chrome";v="100"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'none',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1'
}

# %%
# and here there is the url we are going to use 

URL = 'https://www.idealista.it/ajax/listingcontroller/livesearchmap.ajax?locationUri=&typology=1&o' \
      'peration=1&freeText=&liveSearch=true&zoom=16&northEast=45.45208275781088%2C+9.20756707023621' \
      '2&southWest=45.444857010779245%2C+9.1729129297638&uid=yk298widt7g0ropgx630dolk7vtndvt4l965nu' \
      'ebvl&adfilter_pricemin=default&adfilter_price=default&adfilter_area=default&adfilter_areamax=' \
      'default&adfilter_auctionability=default&adfilter_countryhouses=&adfilter_rooms_1=&adfilter_' \
      'rooms_2=&adfilter_rooms_3=&adfilter_rooms_4=&adfilter_rooms_5_more=&adfilter_baths_1=&adfilte' \
      'r_baths_2=&adfilter_baths_3=&adfilter_newconstruction=&adfilter_goodcondition=&adfilter_tobere' \
      'stored=&adfilter_hasairconditioning=&adfilter_wardrobes=&adfilter_lift=&adfilter_parkingspace=' \
      '&adfilter_garden=&adfilter_swimmingpool=&adfilter_hasterrace=&adfilter_boxroom=&adfilter_acces' \
      'sibleHousing=&adfilter_top_floor=&adfilter_intermediate_floor=&adfilter_ground_floor=&adfilter' \
      '_hasplan=&adfilter_digitalvisit=&adfilter_published=default&adfilter_onlyflats=&adfilter_penth' \
      'ouse=&adfilter_duplex=&adfilter_homes=&adfilter_independent=&adfilter_semidetached=&adfilter_t' \
      'erraced=&adfilter_villa=&adfilter_chalets='

# %% [markdown]
# here we need to use `json` to extract the link of our houses

# %%
# notice the headers = HEADERS, without it, print page would return an: Error 403

page = requests.get(URL, headers=HEADERS)

print(page)
# Out:
# <Response [200]>

# %% [markdown]
# `<Response [200]>` is perfect

# %%
# here we extract the json code

parsedContent = json.loads(page.content)

# print(parsedContent)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/kw/j5qw4n4x75dgp0jx_r4pxc780000gn/T/ipykernel_40392/3512680646.py in <module>
#       1 # here we extract the json code
#       2
# ----> 3 parsedContent = json.loads(page.content)
#       4
#       5 print(parsedContent[:10])
#
# /Applications/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /Applications/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /Applications/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# and this is the same that you would see if you click on [URL](https://www.idealista.it/ajax/listingcontroller/livesearchmap.ajax?locationUri=&typology=1&operation=1&freeText=&liveSearch=true&zoom=16&northEast=45.45208275781088%2C+9.207567070236212&southWest=45.444857010779245%2C+9.1729129297638&uid=yk298widt7g0ropgx630dolk7vtndvt4l965nuebvl&adfilter_pricemin=default&adfilter_price=default&adfilter_area=default&adfilter_areamax=default&adfilter_auctionability=default&adfilter_countryhouses=&adfilter_rooms_1=&adfilter_rooms_2=&adfilter_rooms_3=&adfilter_rooms_4=&adfilter_rooms_5_more=&adfilter_baths_1=&adfilter_baths_2=&adfilter_baths_3=&adfilter_newconstruction=&adfilter_goodcondition=&adfilter_toberestored=&adfilter_hasairconditioning=&adfilter_wardrobes=&adfilter_lift=&adfilter_parkingspace=&adfilter_garden=&adfilter_swimmingpool=&adfilter_hasterrace=&adfilter_boxroom=&adfilter_accessibleHousing=&adfilter_top_floor=&adfilter_intermediate_floor=&adfilter_ground_floor=&adfilter_hasplan=&adfilter_digitalvisit=&adfilter_published=default&adfilter_onlyflats=&adfilter_penthouse=&adfilter_duplex=&adfilter_homes=&adfilter_independent=&adfilter_semidetached=&adfilter_terraced=&adfilter_villa=&adfilter_chalets=
# ) link
#
#
# to better understand the `json` code you can use some sites that "prettify" the code like: [this](http://json.parser.online.fr/)
#
#
# here you can see that the `json` is like a gigantic dictionary where a lot of stuff are inside other stuff, so its important to understand what is inside what
#
#
# What we need is `adId`, all the link of the different houses are like https://www.idealista.it/immobile/24517268/, `adId` in this case is `24517268`, we need to extract all of them
#
#
# Trough the json viewer we see that `adId` its inside `items`, inside `map` and finally inside `jsonResponse`

# %%
print(parsedContent["jsonResponse"]["map"]["items"][:5])
# Out:
# [{'adId': 23977397, 'adOperationId': 1, 'adTypologyId': 1, 'desc': '', 'detailURL': '', 'iconType': 0, 'latitude': 45.4451405, 'longitude': 9.1773548, 'numPics': 0, 'picturesURL': '', 'price': '', 'promocion': False, 'textInfo': '', 'thumbnail': ''}, {'adId': 24373224, 'adOperationId': 1, 'adTypologyId': 1, 'desc': '', 'detailURL': '', 'iconType': 0, 'latitude': 45.4459747, 'longitude': 9.1752586, 'numPics': 0, 'picturesURL': '', 'price': '', 'promocion': False, 'textInfo': '', 'thumbnail': ''}, {'adId': 23192813, 'adOperationId': 1, 'adTypologyId': 1, 'desc': '', 'detailURL': '', 'iconType': 1, 'latitude': 45.4475215, 'longitude': 9.1780672, 'numPics': 0, 'picturesURL': '', 'price': '', 'promocion': False, 'textInfo': '', 'thumbnail': ''}, {'adId': 23967241, 'adOperationId': 1, 'adTypologyId': 1, 'desc': '', 'detailURL': '', 'iconType': 1, 'latitude': 45.4490785, 'longitude': 9.181112, 'numPics': 0, 'picturesURL': '', 'price': '', 'promocion': False, 'textInfo': '', 'thumbnail': ''}, {'adId': 24424153, 'adOperationId': 1, 'adTypologyId': 1, 'desc': '', 'detailURL': '', 'iconType': 0, 'latitude': 45.4470215, 'longitude': 9.1781672, 'numPics': 0, 'picturesURL': '', 'price': '', 'promocion': False, 'textInfo': '', 'thumbnail': ''}]

# %% [markdown]
# since its a list we can access the first element and extract the first `adId`:

# %%
print(parsedContent["jsonResponse"]["map"]["items"][0]["adId"])
# Out:
# 23977397

# %% [markdown]
# now we need to extract all of them, first we extract the total number of `adId`

# %%
max_houses = parsedContent["jsonResponse"]["total"]

print(max_houses)
# Out:
# 346

# %% [markdown]
# ok so we have a total of 346 houses

# %%
id_list = []

for i in range(int(max_houses)):
    id_list.append(parsedContent["jsonResponse"]["map"]["items"][i]["adId"])

print(id_list[:20])
# Out:
# [23977397, 24373224, 23192813, 23967241, 24424153, 22152618, 23989651, 22161576, 23947727, 24425353, 24032179, 24079647, 24390305, 23986283, 23267628, 24505279, 23068226, 24069576, 24446954, 24510480]

# %% [markdown]
# top, now we need to create the links and we are done

# %%
link_list = []
url = 'https://www.idealista.it/immobile/'

for id in id_list:
    link_list.append(url + str(id) + '/')

print(link_list[:20])
# Out:
# ['https://www.idealista.it/immobile/23977397/', 'https://www.idealista.it/immobile/24373224/', 'https://www.idealista.it/immobile/23192813/', 'https://www.idealista.it/immobile/23967241/', 'https://www.idealista.it/immobile/24424153/', 'https://www.idealista.it/immobile/22152618/', 'https://www.idealista.it/immobile/23989651/', 'https://www.idealista.it/immobile/22161576/', 'https://www.idealista.it/immobile/23947727/', 'https://www.idealista.it/immobile/24425353/', 'https://www.idealista.it/immobile/24032179/', 'https://www.idealista.it/immobile/24079647/', 'https://www.idealista.it/immobile/24390305/', 'https://www.idealista.it/immobile/23986283/', 'https://www.idealista.it/immobile/23267628/', 'https://www.idealista.it/immobile/24505279/', 'https://www.idealista.it/immobile/23068226/', 'https://www.idealista.it/immobile/24069576/', 'https://www.idealista.it/immobile/24446954/', 'https://www.idealista.it/immobile/24510480/']

# %% [markdown]
# lets try one link: https://www.idealista.it/immobile/23977397/
#
# ok perfect, now we have all of our link and for the moment we are done with `json`

# %% [markdown]
# ## scraping of single house link info
#
# Now we need to extract the info from the link we have created: for this reason I have build the function `scrape_page` that receive as input the url of the house of interest and (for the moment) extract and only print the informations:

# %%
def scrape_page(url):
    # input: url of the house
    # output: row with all the desired info to insert in the df

    page = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(page.content, 'lxml')
    print(url)
    title = soup.find('span', class_='main-info__title-main')
    title = title.get_text()
    print(title)
    place = soup.find('span', class_='main-info__title-minor')
    place = place.get_text()
    print(place)
    price = soup.find('span', class_='txt-bold')
    price = price.get_text()
    print(price + ' €')
    info = soup.find('div', class_='info-features')
    size = info.find('span').find('span')
    size = size.get_text()
    print(size + ' m^2')

# %% [markdown]
# but before using `scrape_page` lets first understand a little bit how an `html` code is made:

# %%
url = link_list[0]

print(url)

page = requests.get(url)

print(page)
# Out:
# https://www.idealista.it/immobile/23977397/
# <Response [403]>

# %% [markdown]
# and thats because we forgot to insert the `headers`

# %%
url = link_list[0]

print(url)

page = requests.get(url, headers=HEADERS)

print(page)
# Out:
# https://www.idealista.it/immobile/23977397/
# <Response [200]>

# %% [markdown]
# and thats what we want!
#
# Now we need to extract the `html` code from `page`

# %%
soup = BeautifulSoup(page.content, 'lxml')

# print(soup)
# Out:
# <!DOCTYPE html>
# <html class="" data-userauth="false" env="it" lang="it" username="">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Appartamento su due piani in vendita in via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano — idealista, N.1 in Italia</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Appartamento su due piani di 110 m², Appartamento su due piani in vendita in via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano, quartiere Navigli-Porta Genova" name="description"/>
# <meta content="idealista.com" name="author"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="no-cache" name="pragma"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="Fri, 01 Jan 1990 00:00:00 GMT" http-equiv="Expires"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="Cache-Control"/>
# <script defer="" src="https://st1.idealista.it/static/common/js/lib/jquery/jquery-1.10.2.js"></script>
# <script src="https://st1.idealista.it/static/common/release/mavericks/legacy/js/didomi/didomi-consent-lang.js"></script>
# <script src="https://st1.idealista.it/static/common/release/mavericks/legacy/js/didomi/didomi-iab-integration.js"></script>
# <script src="https://st1.idealista.it/static/common/release/mavericks/legacy/js/didomi/didomi-embed.js"></script>
# <script src="https://st1.idealista.it/static/common/release/mavericks/legacy/js/tealium/tealium-wrapper.js?20220412102208"></script>
# <link href="https://st1.idealista.it/favicon.ico?20220412102208" rel="shortcut icon"/>
# <link href="https://st1.idealista.it/static/common/icons/32x32.png?20220412102208" rel="apple-touch-icon" sizes="32x32"/>
# <link href="https://st1.idealista.it/static/common/icons/32x32.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/57x57.png?20220412102208" rel="apple-touch-icon" sizes="57x57"/>
# <link href="https://st1.idealista.it/static/common/icons/57x57.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/60x60.png?20220412102208" rel="apple-touch-icon"/>
# <link href="https://st1.idealista.it/static/common/icons/60x60.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/76x76.png?20220412102208" rel="apple-touch-icon" sizes="76x76"/>
# <link href="https://st1.idealista.it/static/common/icons/76x76.png?20220412102208" rel="apple-touch-icon-precomposed" sizes="76x76"/>
# <link href="https://st1.idealista.it/static/common/icons/96x96.png?20220412102208" rel="apple-touch-icon" sizes="96x96"/>
# <link href="https://st1.idealista.it/static/common/icons/96x96.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/120x120.png?20220412102208" rel="apple-touch-icon" sizes="120x120"/>
# <link href="https://st1.idealista.it/static/common/icons/120x120.png?20220412102208" rel="apple-touch-icon-precomposed" sizes="120x120"/>
# <link href="https://st1.idealista.it/static/common/icons/128x128.png?20220412102208" rel="apple-touch-icon" sizes="128x128"/>
# <link href="https://st1.idealista.it/static/common/icons/128x128.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/144x144.png?20220412102208" rel="apple-touch-icon" sizes="144x144"/>
# <link href="https://st1.idealista.it/static/common/icons/144x144.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/152x152.png?20220412102208" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://st1.idealista.it/static/common/icons/152x152.png?20220412102208" rel="apple-touch-icon-precomposed" sizes="152x152"/>
# <link href="https://st1.idealista.it/static/common/icons/167x167.png?20220412102208" rel="apple-touch-icon" sizes="167x167"/>
# <link href="https://st1.idealista.it/static/common/icons/167x167.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/180x180.png?20220412102208" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://st1.idealista.it/static/common/icons/180x180.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/192x192.png?20220412102208" rel="apple-touch-icon" sizes="192x192"/>
# <link href="https://st1.idealista.it/static/common/icons/192x192.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/195x195.png?20220412102208" rel="apple-touch-icon" sizes="195x195"/>
# <link href="https://st1.idealista.it/static/common/icons/195x195.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link href="https://st1.idealista.it/static/common/icons/196x196.png?20220412102208" rel="apple-touch-icon" sizes="196x196"/>
# <link href="https://st1.idealista.it/static/common/icons/196x196.png?20220412102208" rel="apple-touch-icon-precomposed"/>
# <link as="style" href="https://st1.idealista.it/static/common/release/detail/detail.css?20220412102208" rel="preload"/>
# <link href="https://st1.idealista.it/static/common/release/detail/detail.css?20220412102208" rel="stylesheet" type="text/css"/>
# <link href="https://www.idealista.it/immobile/23977397/" rel="canonical"/>
# <meta content="NOODP,INDEX, FOLLOW" name="ROBOTS"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0" name="viewport"/>
# <meta content="https://img3.idealista.it/blur/WEB_DETAIL-M-L/0/id.pro.it.image.master/4d/4b/46/389044302.jpg" property="og:image"/>
# <meta content="1500" property="og:image:width"/>
# <meta content="1000" property="og:image:height"/>
# <link href="https://www.idealista.it/en/immobile/23977397/" hreflang="en" rel="alternate"/><link href="https://www.idealista.it/es/immobile/23977397/" hreflang="es" rel="alternate"/><link href="https://www.idealista.it/fr/immobile/23977397/" hreflang="fr" rel="alternate"/><link href="https://www.idealista.it/de/immobile/23977397/" hreflang="de" rel="alternate"/><link href="https://www.idealista.it/pt/immobile/23977397/" hreflang="pt" rel="alternate"/><link href="https://www.idealista.it/da/immobile/23977397/" hreflang="da" rel="alternate"/><link href="https://www.idealista.it/fi/immobile/23977397/" hreflang="fi" rel="alternate"/><link href="https://www.idealista.it/no/immobile/23977397/" hreflang="no" rel="alternate"/><link href="https://www.idealista.it/nl/immobile/23977397/" hreflang="nl" rel="alternate"/><link href="https://www.idealista.it/pl/immobile/23977397/" hreflang="pl" rel="alternate"/><link href="https://www.idealista.it/ro/immobile/23977397/" hreflang="ro" rel="alternate"/><link href="https://www.idealista.it/ru/immobile/23977397/" hreflang="ru" rel="alternate"/><link href="https://www.idealista.it/sv/immobile/23977397/" hreflang="sv" rel="alternate"/><link href="https://www.idealista.it/el/immobile/23977397/" hreflang="el" rel="alternate"/><link href="https://www.idealista.it/zh/immobile/23977397/" hreflang="zh" rel="alternate"/>
# <link as="font" crossorigin="" href="https://st1.idealista.it/static/common/release/modules/resources/fonts/bernino-regular.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.it/static/common/release/modules/resources/fonts/bernino-bold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.it/static/common/release/modules/resources/fonts/bernino-semibold.woff?v1" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="https://st1.idealista.it/static/common/release/modules/resources/fonts/idealista-regular.woff?v71" rel="preload" type="font/woff"/>
# <script>
# 			var isCloseOutsideModalDisableMobileToggle = true;
# 		</script>
# </head>
# <body class="" id="">
# <script>
#     var utag_data = {"page":{"section":"portal","subSection":"detail","name":"home","language":"it","category":"detail","subCategory":"","subSubCategory":"","template":"detail","position":""},"user":{"status":"2"},"response":{"statusCode":"200","loadBalancer":"web"},"ad":{"id":"23977397","operation":"1","typology":"1","address":{"municipalityId":"0-EU-IT-MI-01-001-135","provinceId":"0-EU-IT-MI","locationId":"0-EU-IT-MI-01-001-135-05-002","locationLevel":"8"},"builtType":"3","energyCertification":{"type":"g","suffix":"italyLegge90"},"price":"620000","characteristics":{"roomNumber":"3","bathNumber":"2","hasLift":"0","hasGarden":"1","constructedArea":"110"},"condition":{"isNewDevelopment":"0","isNeedsRenovating":"0","isGoodCondition":"1"},"media":{"photoNumber":"64","videoNumber":"0","hasFloorPlan":"1","has3Dtour":"0","hasHomeStaging":"0"},"owner":{"type":"2","commercialId":"","commercialName":"imi-immobiliare-milano-case-navigli","contactPreference":"1","chatIsActive":"0"},"origin":"11","isRecommended":"0","hasRecommended":"0","numberRecommended":"topHighlight","originTypeRecommended":"","typeRecommended":"","isAuction":"0","recommendationId":"","vtRecommendationAdId":"","vtRecommendationId":""},"search":{"operation":"1","typology":"1","geo":{"type":"OFFICIAL_ZONE","locationId":"0-EU-IT-MI-01-001-135-05-002","locationLevel":"8"},"orderBy":"relevance-desc"},"correlation":{"id":"44d1b19f-fc4b-4a17-a96a-c9dee9e90396","session":"69e89c36-4e0b-417d-a8cf-21a6041320a6"},"event":{"id":"","type":"","name":"","action":"","role":"","user_role":"","channel":"","origin":"","outcome":"","hash":"","markup":{"xtPage":"","name":"","category":"","subCategory":"","subSubCategory":""},"productType":"","agencyNames":[],"transactionId":""},"didomiVendorsConsent":"","post":{"id":"a573cc3a-f77f-465c-b72e-b2e1cb3de5ec","time":"1649839840257"}};
# 	var dataLayerContext = utag_data;
#
#
#         window.utag_cfg_ovrd = { noview: true };
#
#     window.utag_data = utag_data;
# </script>
# <script>
#     (function(a,b,c,d){
#         a='//tags.tiqcdn.com/utag/idealista/it-portal/prod/utag.js';
#         b=document;c='script';d=b.createElement(c);d.onload=function () { window.idealistaUtag && window.idealistaUtag.init() };d.src=a;d.type='text/java'+c;d.defer=true;
#         a=b.getElementsByTagName(c)[0];a.parentNode.insertBefore(d,a);
#     })();
# </script>
# <script>
#     var didomiActive = true;
#     if(!false) {
#         function onInitIdealistaUtag() {
#             window.utag.view(window.utag_data);
#         }
#
#         if (window.idealistaUtag) {
#             window.idealistaUtag.onInit(onInitIdealistaUtag);
#         }
#
#     }
#     if(false && !didomiActive){
#         window.utag_cfg_ovrd = { noview: true };
#     }
# </script>
# <header class="help-center ide-header" id="main-header">
# <div class="col-ide-lg-12 col-ide-xl-12 content">
# <figure class="logo-container claim-it">
# <a class="id-logo" href="/"> <img alt="idealista" src="https://st1.idealista.it/static/common/img/idealista.svg" title="idealista"/></a>
# <span class="claim-it-text">il N.1 in Italia</span>
# </figure>
# <nav>
# <div class="lang-selector lang-responsive">
# <span class="lang-selector--lang-selected icon-arrow-dropdown">
# <span class="flag lang-it"></span>
# <span class="lang-text">Italiano</span>
# </span>
# <ul class="lang-selector--lang-options" data-url-attribute="/user/update-user-language" data-user-authenticated="false">
# <li>
# <a data-markup="cambio::idioma::cabecera::en" href="/en/immobile/23977397/" id="idioma-en" rel="nofollow" value="en">
# <span>
# <span class="flag lang-en"></span>English
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::es" href="/es/immobile/23977397/" id="idioma-es" rel="nofollow" value="es">
# <span>
# <span class="flag lang-es"></span>Español
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::fr" href="/fr/immobile/23977397/" id="idioma-fr" rel="nofollow" value="fr">
# <span>
# <span class="flag lang-fr"></span>Français
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::de" href="/de/immobile/23977397/" id="idioma-de" rel="nofollow" value="de">
# <span>
# <span class="flag lang-de"></span>Deutsch
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::pt" href="/pt/immobile/23977397/" id="idioma-pt" rel="nofollow" value="pt">
# <span>
# <span class="flag lang-pt"></span>Português
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::da" href="/da/immobile/23977397/" id="idioma-da" rel="nofollow" value="da">
# <span>
# <span class="flag lang-da"></span>Dansk
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::fi" href="/fi/immobile/23977397/" id="idioma-fi" rel="nofollow" value="fi">
# <span>
# <span class="flag lang-fi"></span>Suomi
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::no" href="/no/immobile/23977397/" id="idioma-no" rel="nofollow" value="no">
# <span>
# <span class="flag lang-no"></span>Norsk
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::nl" href="/nl/immobile/23977397/" id="idioma-nl" rel="nofollow" value="nl">
# <span>
# <span class="flag lang-nl"></span>Nederlands
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::pl" href="/pl/immobile/23977397/" id="idioma-pl" rel="nofollow" value="pl">
# <span>
# <span class="flag lang-pl"></span>Polski
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::ro" href="/ro/immobile/23977397/" id="idioma-ro" rel="nofollow" value="ro">
# <span>
# <span class="flag lang-ro"></span>Română
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::ru" href="/ru/immobile/23977397/" id="idioma-ru" rel="nofollow" value="ru">
# <span>
# <span class="flag lang-ru"></span>Русский
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::sv" href="/sv/immobile/23977397/" id="idioma-sv" rel="nofollow" value="sv">
# <span>
# <span class="flag lang-sv"></span>Svenska
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::el" href="/el/immobile/23977397/" id="idioma-el" rel="nofollow" value="el">
# <span>
# <span class="flag lang-el"></span>Ελληνικά
# </span>
# </a>
# </li>
# <li>
# <a data-markup="cambio::idioma::cabecera::zh" href="/zh/immobile/23977397/" id="idioma-zh" rel="nofollow" value="zh">
# <span>
# <span class="flag lang-zh"></span>中文
# </span>
# </a>
# </li>
# <li class="separator">
# <a data-markup="cambio::pais::cabecera::com" href="https://www.idealista.com/it/" title="">idealista.com</a>
# </li>
# <li>
# <a data-markup="cambio::pais::cabecera::pt" href="https://www.idealista.pt/it/" title="">idealista.pt</a>
# </li>
# </ul>
# </div>
# <ul class="no-logged-user-menu ide-main-menu" id="no-login-user-bar">
# <li class="ide-main-menu__adv-free" id="put-adv-free">
# <a data-markup="header-new-advert" href="/info/pubblica-annuncio">
# <span class="icon-pin">
# Inserisci annunci gratis
# </span>
# </a>
# </li>
# <li id="your-account">
# <a class="icon-user-no-logged" data-markup="header-login" href="/login" rel="nofollow">
# <span class="icon-user-no-logged-text">Il tuo account</span>
# <span class="icon-user-no-logged-text-extrasmall-devices">Il tuo account</span>
# </a>
# </li>
# </ul>
# </nav>
# </div>
# </header>
# <div id="wrapper">
# <div data-islogged="false" id="main">
# <div class="container">
# <div class="detail-pagination" id="pager">
# <div class="content detail-first-picture">
# <nav class="detail-pagination--back">
# <a class="btn nav back icon-arrow-double-left" data-markup="backToList_subHeader" href="/vendita-case/milano/navigli-bocconi/navigli-porta-genova/" title="Case a Navigli-Porta Genova">
# Case a Navigli-Porta Genova
# </a>
# </nav>
# <p class="detail-pagination--count">
# </p>
# <nav class="detail-pagination--prev-next">
# </nav>
# </div>
# </div>
# <main class="detail-container">
# <picture class="main-image main-image-desktop horizontal-img false-panoramic image-loaded">
# <div class="main-image_first" data-relative-position="0" position="0">
# <img alt="Immagine Sala di appartamento su due piani su via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano" class="image-focus show image-focus show" data-orientation="horizontal" src="https://img3.idealista.it/blur/WEB_DETAIL_TOP-L-L/0/id.pro.it.image.master/4d/4b/46/389044302.jpg" title="Immagine Sala di appartamento su due piani su via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano"/>
# </div>
# </picture>
# <section class="main-image main-image-device">
# <div class="swipe-mask-wrapper">
# <div class="swipe-mask">
# <picture class="swipe-image">
# <img alt="Immagine Sala di appartamento su due piani su via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano" src="https://img3.idealista.it/blur/WEB_DETAIL_TOP-L-L/0/id.pro.it.image.master/4d/4b/46/389044302.jpg" title="Immagine Sala di appartamento su due piani su via Evangelista Torricelli, 20, Navigli-Porta Genova, Milano"/>
# </picture>
# </div>
# </div>
# </section>
# <section class="detail-info ide-box-detail-first-picture ide-box-detail--reset overlay-box">
# <div class="fake-anchors corevitals-fixed-height"></div>
# <nav class="sticky-bar-detail" id="fixed-toolbar">
# <div class="content clearfix col-ide-lg-12 col-ide-xl-12">
# <a class="nav back icon-arrow-double-left" data-markup="backToList_toolbar" href="/vendita-case/milano/navigli-bocconi/navigli-porta-genova/" title="Case a Navigli-Porta Genova"></a>
# <div class="main-info">
# <h2 class="txt-body">
# <span>Appartamento su due piani in vendita in via Evangelista Torricelli, 20</span>
# </h2>
# <strong class="typology">
# appartamento
# </strong>
# <p class="info-data txt-big">
# <span class="price-container">
# <strong class="price">620.000 €</strong>
# </span>
# <span>
# <span>110</span>
# m2
# </span>
# <span>
# <span>3</span>
# locali
# </span>
# <span>
# <span>Piano terra</span>
# senza ascensore
# </span>
# </p>
# </div>
# <div class="links">
# <button class="favorite-btn btn regular" data-markup="favourite-toolbar" data-markup-add="favourite-toolbar" data-markup-remove="remove-favourite-toolbar" data-role="add" data-text-add='Salva&lt;span class="hide-txt"&gt; preferito&lt;/span&gt;' data-text-remove="Preferito"></button>
# <i class="icon-heart" role="image"></i>
# <span>Salva<span class="hide-txt"> preferito</span></span>
# <button class="discard-btn icon-delete" data-markup="discard-toolbar" data-markup-add="discard-toolbar" data-markup-remove="recover-toolbar" data-role="add" data-text-add="Elimina" data-text-remove="Recuperare"></button>
# <span>Elimina</span>
# </div>
# </div>
# </nav>
# <div class="main-info__title">
# <h1 class="">
# <span class="main-info__title-main">Appartamento su due piani in vendita in via Evangelista Torricelli, 20</span>
# </h1>
# <span class="main-info__title-block">
# <span class="main-info__title-minor">Navigli-Porta Genova, Milano</span>
# <a class="main-info__title-map icon-location showMap" data-markup-map="detalle::map::top" href="#"><span>Vedi mappa</span></a>
# </span>
# </div>
# <div class="info-data">
# <span class="info-data-price"><span class="txt-bold">620.000</span> €</span>
# </div>
# <div class="info-tags">
# <span class="txt-mortgage">
# <span>
# <a class="icon-barchart" data-markup="calculate-mortgage-top" href="/mutui/hipoteca-para-comprar-casa?adId=23977397&amp;xtatc=INT-8-[detalle_personalizar_hipoteca_consecutivo]" target="_blank">
# <span>Calcola mutuo</span>
# </a>
# </span>
# </span>
# <span class="txt-mortgage">
# <span class="applyMortgageContainer">
# <a class="icon-edit applyMortgage js-affida-popup" data-button-xiti="form-mortgages-top" data-markup="form-mortgages-top" href="#">
# <span>Studio mutuo</span>
# </a>
# </span>
# </span>
# </div>
# <div class="info-features">
# <span>
# <span>110</span>
# m2
# </span>
# <span>
# <span>3</span>
# locali
# </span>
# <span>
# <span>Piano terra</span>
# senza ascensore
# </span>
# <div class="info-features-tags">
# </div>
# </div>
# <div class="links-detail-info" id="links">
# <a class="favorite-btn" data-markup="favourite" data-markup-add="favourite" data-markup-remove="remove-favourite" data-role="add" data-text-add='Salva&lt;span class="hide-txt"&gt; preferito&lt;/span&gt;' data-text-remove="Preferito" href="#">
# <i class="icon-heart" role="image"></i>
# <span>Salva<span class="hide-txt"> preferito</span></span>
# </a>
# <a class="discard-btn icon-delete" data-markup="discard" data-markup-add="discard" data-markup-remove="recover" data-role="add" data-text-add="Elimina" data-text-remove="Recuperare" href="#">
# <span>Elimina</span>
# </a>
# <a class="icon-share" href="#" id="share-friend-link" title="Condividi">
# <span>Condividi</span>
# </a>
# </div>
# <div class="comment-wrapper" id="comment-wrapper">
# <span class="print-title">Nota personale</span>
# <div class="text-wrapper">
# <span class="comment-text" id="comment-text"></span>
# <a class="edit-title-mobile">Modifica</a>
# <a class="edit-title">Modifica nota</a>
# </div>
# <div class="textarea-wrapper">
# <span class="icon-note"></span>
# <textarea class="comment-textarea" data-chars-counter="1000" id="comment-textarea" maxlength="1000" placeholder="Inserisci un commento personale (potrai vederlo solo tu)" spellcheck="false"></textarea>
# </div>
# </div>
# <div class="commentsContainer" data-url="/ajax/comment.ajax">
# <h3 class="comments-h3">Commento dell’inserzionista</h3>
# <div class="select-comment-lang">
# Disponibile in
# <a class="current" data-lang="it" href="#">Italiano</a>
# <a data-lang="en" href="#">English</a>
# <a class="optionalLanguage" data-lang="es" href="#" style="display:none">Español</a>
# <a class="optionalLanguage" data-lang="fr" href="#" style="display:none">Français</a>
# <a class="optionalLanguage" data-lang="de" href="#" style="display:none">Deutsch</a>
# <a class="optionalLanguage" data-lang="pt" href="#" style="display:none">Português</a>
# <a class="optionalLanguage" data-lang="da" href="#" style="display:none">Dansk</a>
# <a class="optionalLanguage" data-lang="fi" href="#" style="display:none">Suomi</a>
# <a class="optionalLanguage" data-lang="no" href="#" style="display:none">Norsk</a>
# <a class="optionalLanguage" data-lang="nl" href="#" style="display:none">Nederlands</a>
# <a class="optionalLanguage" data-lang="pl" href="#" style="display:none">Polski</a>
# <a class="optionalLanguage" data-lang="ro" href="#" style="display:none">Română</a>
# <a class="optionalLanguage" data-lang="ru" href="#" style="display:none">русский</a>
# <a class="optionalLanguage" data-lang="sv" href="#" style="display:none">Svenska</a>
# <a class="optionalLanguage" data-lang="el" href="#" style="display:none">Ελληνικά</a>
# <a class="optionalLanguage" data-lang="zh" href="#" style="display:none">中文</a>
# <nav class="other-comments-lang">
# <span>
# <span>Altre lingue</span>
# <i class="icon-arrow-dropdown"></i>
# </span>
# <ul>
# <li class="selectorLanguage" data-lang="es">
# <a class="selectorLanguage" data-lang="es" href="#">Español</a>
# </li>
# <li class="selectorLanguage" data-lang="fr">
# <a class="selectorLanguage" data-lang="fr" href="#">Français</a>
# </li>
# <li class="selectorLanguage" data-lang="de">
# <a class="selectorLanguage" data-lang="de" href="#">Deutsch</a>
# </li>
# <li class="selectorLanguage" data-lang="pt">
# <a class="selectorLanguage" data-lang="pt" href="#">Português</a>
# </li>
# <li class="selectorLanguage" data-lang="da">
# <a class="selectorLanguage" data-lang="da" href="#">Dansk</a>
# </li>
# <li class="selectorLanguage" data-lang="fi">
# <a class="selectorLanguage" data-lang="fi" href="#">Suomi</a>
# </li>
# <li class="selectorLanguage" data-lang="no">
# <a class="selectorLanguage" data-lang="no" href="#">Norsk</a>
# </li>
# <li class="selectorLanguage" data-lang="nl">
# <a class="selectorLanguage" data-lang="nl" href="#">Nederlands</a>
# </li>
# <li class="selectorLanguage" data-lang="pl">
# <a class="selectorLanguage" data-lang="pl" href="#">Polski</a>
# </li>
# <li class="selectorLanguage" data-lang="ro">
# <a class="selectorLanguage" data-lang="ro" href="#">Română</a>
# </li>
# <li class="selectorLanguage" data-lang="ru">
# <a class="selectorLanguage" data-lang="ru" href="#">русский</a>
# </li>
# <li class="selectorLanguage" data-lang="sv">
# <a class="selectorLanguage" data-lang="sv" href="#">Svenska</a>
# </li>
# <li class="selectorLanguage" data-lang="el">
# <a class="selectorLanguage" data-lang="el" href="#">Ελληνικά</a>
# </li>
# <li class="selectorLanguage" data-lang="zh">
# <a class="selectorLanguage" data-lang="zh" href="#">中文</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="comment">
# <div class="adCommentsLanguage expandable is-expandable" data-compressed-max-length="1650">
# <p>
# Ad. ze Corso San Gottardo/Navigli - Via Torricelli<br/><br/>Proponiamo, a pochi passi da Corso San Gottardo e, quindi, in una delle zone più antiche e famose della città, a breve distanza dai locali e dai negozi vintage che costeggiano i Navigli in tutta la loro estensione, nonché a breve distanza da due importanti poli universitari (Naba e Bocconi), INTROVABILE soluzione immobiliare unica nel suo genere, completamente INDIPENDENTE, in tipologia VILLINO, di mq 110 c. a commerciali e così composta:<br/><br/>GIARDINO, di mq 75 pavimentato e piantumato, che dà accesso alla soluzione immobiliare.<br/>PIANO TERRA: ingresso, ampia zona living, cucina ad isola completamente attrezzata, bagno finestrato con vasca.<br/>PIANO PRIMO: una scala (con scalini a sbalzo) dà accesso alla zona notte che è composta da due camere da letto, cabina armadio e bagno finestrato con box doccia.<br/><br/>Il villino è stato completamente ristrutturato con finiture di pregio ed è caratterizzato da un inconfondibile stile. La zona living è spaziosa e la DOPPIA esposizione, così come il buon orientamento, consentono alla luce di irradiare la soluzione valorizzandone le finiture; i colori tenui e la presenza del parquet, donano alla casa un’atmosfera calda e accogliente.<br/><br/>Tra le caratteristiche tecniche troverete infissi in doppio vetro, impianto di aria condizionata, riscaldamento autonomo ecc. e la soluzione immobiliare si presta ad essere abitata sin da subito.<br/><br/>Ideale per chi cerca una soluzione giovane, contemporanea, inserita in una delle zone più richieste di Milano.<br/><br/>Libera al rogito.
# </p>
# </div>
# </div>
# <div class="spinnerTranslations" style="display: none">
# <div class="googleTranslateLogo">
# <img loading="lazy" src="https://st1.idealista.it/static/common/release/detail/resources/img/loading.gif"/>
# </div>
# </div>
# <div class="spinnerTranslationsMobile" style="display: none">
# <div class="googleTranslateLogo">
# <img loading="lazy" src="https://st1.idealista.it/static/common/release/detail/resources/img/loading-mobile.gif"/>
# </div>
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="it" style="display: none">
# Ci dispiace, al momento non è possibile tradurre il commento. Riprova più tardi.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="en" style="display: none">
# Sorry, we can't translate this description right now. Please try again later.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="es" style="display: none">
# Lo sentimos, no es posible traducir el comentario en estos momentos. Prueba de nuevo más tarde.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="fr" style="display: none">
# Nous sommes désolés, nous ne pouvons pas traduire de commentaire pour l'instant. Veuillez réessayer plus tard.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="de" style="display: none">
# Leider kann die Beschreibung im Augenblick nicht übersetzt werden. Bitte versuchen Sie es später noch einmal.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="pt" style="display: none">
# Lamentamos, não é possível traduzir o comentário neste momento. Volta a tentar mais tarde.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="da" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="fi" style="display: none">
# Kommenttia ei valitettavasti voida tällä hetkellä kääntää. Yritä myöhemmin uudelleen.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="no" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="nl" style="display: none">
# Sorry, het is niet mogelijk om de reactie op dit moment te vertalen. Probeer het later opnieuw.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="pl" style="display: none">
# Niestety, obecnie nie można przetłumaczyć tego komentarza. Spróbuj ponownie później.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="ro" style="display: none">
# Ne pare rău, pentru moment, nu este posibilă traducerea comentariului. Încearcă din nou mai târziu.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="ru" style="display: none">
# К сожалению, перевод комментария в данный момент невозможен. Попробуйте еще раз позже.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="sv" style="display: none">
# Vi ber om ursäkt, det är inte möjligt att översätta den här kommentaren just nu. Försök igen senare.
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="el" style="display: none">
# </div>
# <div class="feedback contextual full-width error icon-feedbk-ko translation-error" data-lang="zh" style="display: none">
# </div>
# </div>
# <section class="details-box" id="details">
# <div class="details-property">
# <div class="details-property-feature-one">
# <h3 class="details-property-h3">Caratteristiche specifiche</h3>
# <div class="details-property_features">
# <ul>
# <li>110 m² commerciali</li>
# <li>3 locali</li>
# <li>2 bagni</li>
# <li>Buono stato</li>
# <li>Armadi a muro</li>
# <li>Orientamento nord, sud, est, ovest</li>
# <li>Costruito nel 1900</li>
# <li> Riscaldamento autonomo: Gas naturale</li>
# <li>Classe energetica (Legge 90 del 2013, legislazione vigente): <span class="icon-energy-c-8" title="g"></span> (186,5 kWh/m² anno)
# </li>
# </ul>
# </div>
# <h3 class="details-property-h3">Costruzione</h3>
# <div class="details-property_features">
# <ul>
# <li>Piano terra</li>
# <li>Senza ascensore</li>
# </ul>
# </div>
# </div>
# <div class="details-property-feature-two">
# <h3 class="details-property-h3">Dotazione</h3>
# <div class="details-property_features">
# <ul>
# <li>
# Aria condizionata
# </li>
# <li>
# Aree verdi
# </li>
# </ul>
# </div>
# </div>
# <div class="details-property-feature-three">
# </div>
# </div>
# </section>
# <section class="details-box date-update-block">
# <span class="icon-feedbk-info"></span>
# <p class="date-update-text">Annuncio aggiornato più di 2 mesi fa</p>
# </section>
# </section>
# <div class="multimedia-content" id="premium-multimedia-container">
# <div id="homestaging" role="img"></div>
# <div class="rs-gallery" id="gallery"></div>
# </div>
# <div class="multimedia-content" id="multimedia-container">
# <div class="images-slider" id="main-multimedia">
# </div>
# </div>
# <section class="mortgages-content" id="mortgages">
# <div class="ide-box-detail overlay-box" id="helpus-improve">
# <h3 class="ide-box-detail-h3 icon-flag">
# Vedi qualche errore?
# </h3>
# <p class="helpus-improve_txt">
# Faccelo sapere per poterlo correggere e aiutare altre persone.
# </p>
# <a class="helpus-improve_notify" data-title="Dicci che errore hai visto" data-xiti-page="detalle::conversiones::form-reportar-error" data-xiti-shared-n2="true" href="#">
# Facci sapere quale errore hai visto
# </a>
# </div>
# <div class="ide-box-detail overlay-box">
# <div class="toggle-price">
# <article class="price-feature clearfix">
# <h2 class="txt-medium txt-bold">Prezzo</h2>
# <section class="price-features__container">
# <p class="flex-feature">
# <span class="flex-feature-details">Prezzo dell'immobile:</span>
# <strong class="flex-feature-details">620.000 €</strong>
# </p>
# <p class="flex-feature squaredmeterprice">
# <span class="flex-feature-details">Prezzo al m²:</span>
# <span class="flex-feature-details">5.636 €/m²</span>
# </p>
# <p class="flex-feature">
# <span class="flex-feature-details">100 €/mese di spese condominiali</span>
# </p>
# <div>
# <p>
# <a class="counter-offer" data-xiti-page="detalle::conversiones::form_contraoferta" data-xiti-shared-n2="true" href="#" title="Fai una controproposta">
# Fai una controproposta
# </a>
# </p>
# <p>
# <a class="favorite-btn price-feature-link" data-role="add" data-targetid="13" data-text-add="Avvisami se diminuisce il prezzo" data-text-remove="Ok, ti avvisiamo se diminuisce il prezzo" data-xiti-click="detalle::conversiones::avisame_si_baja" data-xiti-shared-n2="true" id="alert-price-down-btn" title="Quanto pagheresti per questo immobile? ti avvisiamo via email se diminuisce il prezzo">Avvisami se diminuisce il prezzo</a>
# </p>
# </div>
# </section>
# </article>
# </div>
# </div>
# <div class="ide-box-detail overlay-box mortgages">
# <article class="simulator clearfix">
# <a class="mortgages__logo" data-markup="detalle::mortgage-logo" href="/mutui/"><span class="icon-font mb-regular"> <span class="icon-idealista-icon"></span> <span class="icon-hipotecas"></span> </span></a>
# <section class="col-ide-lg-8" id="simulator-container">
# <div class="item-form item-redils js-buying-price-slider buying-price">
# <label>
# <span class="txt-medium">Prezzo dell'immobile</span>
# </label>
# <div class="input-container">
# <span class="symbol">€</span>
# <input data-input="" maxlength="12" name="buyingPrice" type="tel"/>
# </div>
# <div data-slider=""></div>
# </div>
# <div class="item-form item-redils js-saving-slider savings">
# <label> <span class="txt-medium">Capitale iniziale</span></label>
# <div class="input-container">
# <span class="symbol">€</span>
# <input data-input="" maxlength="9" name="givenAmount" type="tel"/>
# <span class="percentage"> %</span>
# </div>
# <div data-slider=""></div>
# </div>
# <div class="feedback contextual full-width warning d-none" id="saving-warning"></div>
# <div class="feedback contextual full-width warning icon-feedbk-info d-none" id="saving-alert"></div>
# <div class="item-form item-redils js-term-slider">
# <label><span class="txt-medium">Durata in anni</span></label>
# <div class="input-container short-value">
# <input data-input="" data-max="40" data-min="5" maxlength="2" name="years" type="tel"/>
# </div>
# <div data-slider=""></div>
# </div>
# <div class="item-form item-redils simulator-rate">
# <label>
# <span class="txt-medium">Tasso d'interesse
# <a class="icon-feedbk-info" data-markup="detalle::interest" href="#" id="rate-info"></a>
# </span>
# </label>
# <ul class="segmented-btn-group clearfix js-rate-type">
# <li>
# <label class="input-radio">
# <input data-value="1" name="interestType" type="radio"/>
# <span><span class="txt-medium">Fisso</span></span>
# </label>
# </li>
# <li>
# <label class="input-radio">
# <input checked="" data-value="2" name="interestType" type="radio"/>
# <span><span class="txt-medium">Variabile</span></span>
# </label>
# </li>
# </ul>
# <div class="item-form item-redils">
# <div class="input-container short-value js-rate-input rate">
# <span class="symbol">%</span>
# <input data-number-input="" maxlength="5" name="taxRate" type="tel"/>
# </div>
# </div>
# </div>
# <div class="simulation-summary">
# <div class="js-price-with-expenses price-expenses flex-feature">
# <span class="txt-medium">Importo del mutuo: </span> <span class="txt-medium txt-bold"><span class="js-result-tmpl" data-template="{{=mortgageAmount}}">-</span> €</span>
# </div>
# <div class="js-montly-rate monthly-rate flex-feature">
# <strong class="txt-medium txt-bold">La tua rata mensile:</strong>
# <strong class="txt-medium txt-bold"><span class="js-result-tmpl" data-template="{{=monthlyRate}}">3.120</span> €</strong>
# </div>
# <div id="minmortgages-alert"></div>
# <div class="flex-feature">
# <span class="txt-medium">Tasse e spese non incluse</span>
# </div>
# </div>
# <div class="item-form">
# <a class="btn regular fullwidth applyMortgage js-affida-popup" data-markup="form-mortgages-bottom">Analizzare il mio caso</a>
# <span>
# Questi risultati sono indicativi, calcolati sulla base dei numeri che hai inserito.
# <a class="simulator-conditions" href="/info/note-legali" target="_blank">Condizioni generali</a>.
# </span>
# </div>
# </section>
# </article>
# </div>
# <div class="ide-box-detail overlay-box">
# <article class="clearfix data-feature">
# <a class="data__logo" href="/data/"><span class="icon-font mb-regular"> <span class="icon-idealista-icon"></span> <span class="icon-data"></span> </span></a>
# <section class="data-features__container">
# <h3 class="ide-box-detail-h3">Quanto vale questa proprietà?</h3>
# <p>Ti inviamo un report con la stima del prezzo di questo immobile e con varie informazioni sulla zona.</p>
# <p class="data-feature-link">
# <a class="" data-markup="detalle::link::product-1202" href="/flow/prezzo-stimato?lang=it&amp;adId=23977397">Compra una stima del prezzo</a>
# </p>
# </section>
# </article>
# </div>
# </section>
# <div class="ide-box-detail overlay-box" id="mapWrapper">
# <div class="clearfix" id="headerMap">
# <h3 class="ide-box-detail-h3">Posizione</h3>
# <ul>
# <li class="header-map-list">
# Via Evangelista Torricelli, 20
# </li>
# <li class="header-map-list">
# Area Residenziale Ad.ze Corso San Gottardo/Navigli
# </li>
# <li class="header-map-list">
# Quartiere Navigli-Porta Genova
# </li>
# <li class="header-map-list">
# Zona Navigli-Bocconi
# </li>
# <li class="header-map-list">
# Milano
# </li>
# </ul>
# </div>
# <div id="map"></div>
# <div class="static-map-container" id="static-map-container">
# <div class="static-map" id="static-map"><a class="showMap" data-markup-map-photo="detalle::map::photo" href="#"></a></div>
# <div id="static-map-text-link"><a class="static-map-text-link showMap icon-search" data-markup-map-link="detalle::map::link" href="#"><span>Ingrandisci mappa</span></a></div>
# </div>
# </div>
# <a id="statsPosition" name="statsPosition"></a>
# <div class="ide-box-detail overlay-box mb-jumbo" id="stats">
# <h3 class="ide-box-detail-h3">Statistiche</h3>
# <p class="stats-text">Annuncio aggiornato il 22 febbraio</p>
# <a class="stats-link" href="#">Vedi numero di visite e contatti di questo annuncio</a>
# <div id="stop-fixed-contact-scroll"></div>
# </div>
# <div class="aditional-link ellipsis" id="aditional-link">
# <h2 class="aditional-link_title txt-body mb-small">Link aggiuntivo</h2>
# <a class="link-withered icon-new-tab" data-markup="detalle::link-external-imi-immobiliare-milano-case-navigli" href="https://imi.it/immobili/ad-ze-corso-san-gottardo-navigli-via-torricelli-20/" rel="nofollow noopener" target="_blank" title="Si apre in una finestra nuova">imi.it/immobili/ad-ze-corso-san-gottardo-navigli-via-torricelli-20/</a>
# </div>
# <aside class="side-content" id="side-content">
# <div class="module-contact-container" id="module-contact-container">
# <section class="module-contact highlight-content" contact-modal-type="detail">
# <input name="typology" type="hidden" value="1"/>
# <div class="module-contact--border">
# <div class="feedback-container-unblock"></div>
# <h3 class="module-contact_title h3-simulated">
# <strong>Chiedi all'inserzionista</strong>
# </h3>
# <div class="advertiser-info">
# <div class="advertiser-info__text advertiser-info__gallery">
# <div></div>
# <p class="advertiser-name">
# IMI Immobiliare Milano Navigli
# </p>
# <div class="shortAdDescription">
# <p class="ellipsis">Appartamento su due piani in vendita in via Evangelista Torricelli, 20</p>
# </div>
# </div>
# </div>
# <div class="ide-box-contact feedback-save-search feedback-container d-none"></div>
# <div class="module-contact_form">
# <form action="" class="form contact" data-service-error="Non abbiamo potuto inviare il tuo messaggio, riprova!" novalidate="">
# <div class="module-contact_feedback">
# <div class="feedback success icon-sent-ok">
# <span class="feedback_message">
# Contattato
# </span>
# <span class="contacted-time">
# </span>
# </div>
# </div>
# <div class="advertiser-comment-container">
# <div class="advertiser-comment item-form no-margin">
# <label>
# <p class="module-contact_contacted-title">Il tuo messaggio è stato</p>
# <textarea class="module-contact_textarea" data-message-required="Dimostra il tuo interesse scrivendo un messaggio" data-validation="required" name="contact-message" placeholder="Hai qualche dubbio? vuoi visitare l’immobile? Chiedi all’inserzionista!">Ciao, questo appartamento mi interessa e mi piacerebbe visitarlo.
# Un saluto</textarea>
# </label>
# </div>
# </div>
# <div class="collapsed-form">
# <div class="item-form">
# <div>
# <label>
# <input name="email2" type="hidden"/>
# <span class="email-label">Il tuo indirizzo mail</span>
# <input autocomplete="email" class="js-email-field" data-contact-data-error="Se indichi un indirizzo email o un numero di telefono potranno risponderti ;-)" data-message-email="Verifica il formato della tua email" data-required-group="contact-data" data-validation="email" name="contact-email" type="email" value=""/>
# </label>
# </div>
# </div>
# <div class="item-form half-items clearfix">
# <div class="phone">
# <label>
# <span class="phone-label">Il tuo telefono</span>
# <div id="contact-phone"></div>
# <input class="js-phone-field" name="contact-phone" type="hidden" value=""/>
# </label>
# </div>
# <div class="name">
# <label>
# <span class="name-label">Il tuo nome</span>
# <input autocomplete="name" class="js-name-field" data-message-contact_name="Questo non sembra un nome" data-message-required="Indica il tuo nome " data-validation="contact_name" name="contact-name" type="text" value=""/>
# </label>
# </div>
# </div>
# <div class="general-errors-container feedback full-width warning icon-feedbk-alert d-none"></div>
# <div class="service-error-container feedback full-width error icon-feedbk-ko d-none"></div>
# <div class="captcha-miniFields d-none" data-service-prefix="">
# <div class="captcha">
# <div class="captcha-img">
# </div>
# </div>
# <div class="item-form half-items clearfix">
# <label>
# <span>Scrivi i numeri e le lettere che vedi sopra</span>
# <div>
# <input autocapitalize="none" autocorrect="off" class="_captcha" name="contact-captcha" type="text"/>
# </div>
# </label>
# <p><a class="captcha-reload" href="#">Non capisci cosa c’è scritto?</a></p>
# </div>
# </div>
# <div class="item-form privacy-policy-container" id="privacy-policy-detail">
# <div>
# <label class="input-checkbox" data-error-name="privacy-policy-checkbox" data-message-checkbox="Per contattare gli utenti devi accettare la politica sulla privacy" data-validation="checkbox">
# <input name="privacy-policy-checkbox" type="checkbox"/>
# <span>
# <span>
# Accetta
# <a href="https://www.idealista.it/assistenzautenti/articoli/politica-sulla-privacy/" target="_blank">politica sulla privacy</a>
# </span>
# </span>
# </label>
# </div>
# </div>
# <div class="item-form recommendations-container" id="recommendations-detail">
# <div>
# <label class="input-checkbox" data-error-name="recommendations-checkbox">
# <input data-markup-recommendations="detalle::conversiones::form_contacto::recomendations-" name="recommendations-checkbox" type="checkbox"/>
# <span>
# <span>
# Ricevi immobili simili a questo da idealista
# </span>
# </span>
# </label>
# </div>
# </div>
# <input name="adId" type="hidden" value="23977397"/>
# <input name="operationId" type="hidden" value="1"/>
# <input id="contact-type" name="type" type="hidden" value="2"/>
# </div>
# <div class="d-none">
# <input name="contact-mail" type="text" value=""/>
# </div>
# <div>
# <input class="btn action txt-bold txt-big desktop" data-contacted="Contatta di nuovo" type="submit" value="Contatta"/>
# <input class="btn action txt-bold txt-big no-desktop" data-contacted="Invia di nuovo" type="submit" value="Invia"/>
# </div>
# </form>
# </div>
# <input name="adId" type="hidden" value="23977397"/>
# <div class="ide-box-contact module-contact-gray contact-data-container">
# <h2 class="txt-big txt-bold mb-small">
# Persona che pubblica l'annuncio
# </h2>
# <div class="contact-phones no-form" id="contact-phones-container">
# <div class="phone last-phone">
# <p class="txt-bold _browserPhone icon-phone"> 0281273022</p>
# </div>
# </div>
# <div class="professional-name">
# <div class="name">
# Professionista
# </div>
# <span>
# IMI Immobiliare Milano Navigli
# <input name="user-name" type="hidden" value="IMI Immobiliare Milano Navigli "/>
# </span>
# <input name="professional" type="hidden"/>
# </div>
# <div class="ad-reference-container">
# <div class="ref-help">
# Codice dell'annuncio
# </div>
# <p class="txt-ref">
# Torricelli 20
# </p>
# </div>
# </div>
# <div class="ide-box-contact module-contact-gray about-container">
# <div class="about-advertiser">
# <div class="advertiser-logo">
# <a href="/pro/imi-immobiliare-milano-case-navigli/">
# <img alt="IMI Immobiliare Milano Navigli" data-ondemand-img="https://st3.idealista.it/6b/ea/65/imi-immobiliare-milano-case-navigli.gif" height="60" src="https://st3.idealista.it/6b/ea/65/imi-immobiliare-milano-case-navigli.gif" width="125"/>
# </a>
# </div>
# </div>
# <div class="advertiser-name-container">
# <a class="about-advertiser-name" href="/pro/imi-immobiliare-milano-case-navigli/" title="IMI Immobiliare Milano Navigli">
# IMI Immobiliare Milano Navigli
# </a>
# <span>milano</span>
# </div>
# </div>
# </div>
# </section>
# <div id="suggestions-ads-desktop"></div>
# </div>
# </aside>
# <nav class="sticky-contact-detail" id="sticky-contact">
# <div class="sticky-contact-user col-ide-xs-6 col-ide-sm-4 two-buttons">
# <div class="sticky-contact-user-info">
# <div class="name">
# Professionista
# </div>
# <span>
# <p class="about-advertiser-name">
# IMI Immobiliare Milano Navigli
# </p>
# </span>
# </div>
# </div>
# <div class="contact-buttons col-ide-xs-12 col-ide-sm-8 two-buttons">
# <a class="_mobilePhone phone-number icon-phone btn action col-ide-xs-6 col-ide-sm-6" href="tel:+39 0281273022" target="_blank">
# <span class="phone-btn-number">0281273022</span>
# <span class="phone-btn-txt">Chiama</span>
# </a>
# <button class="contact-fake email-btn icon-chat btn action col-ide-xs-6 col-ide-sm-6" data-role="">
# <span>Contatta</span>
# </button>
# </div>
# </nav>
# </main>
# <div class="idealista-banner-wrapper">
# </div>
# </div>
# </div>
# </div>
# <section class="links-block-home">
# <div class="content">
# <nav>
# <h3>
# Stai cercando un immobile?
# </h3>
# <ul>
# <li>
# <a href="/" title="Ricerca immobili">
# Ricerca immobili
# </a>
# </li>
# <li>
# <a href="/properties-for-sale-in-italy" title="Vendita di case e appartamenti in Italia">
# Vendita di case e appartamenti in Italia
# </a>
# </li>
# <li>
# <a href="/long-term-rentals-in-italy" title="Affitto di case e appartamenti in Italia">
# Affitto di case e appartamenti in Italia
# </a>
# </li>
# <li>
# <a href="/case-in-affitto" title="Case e appartamenti in affitto">
# Case e appartamenti in affitto
# </a>
# </li>
# <li>
# <a href="/stanze-in-affitto" title="Appartamenti in condivisione">
# Appartamenti in condivisione
# </a>
# </li>
# <li>
# <a href="https://it.rentalia.com/" title="Rentalia, affitto vacanze">
# Rentalia, affitto vacanze
# </a>
# </li>
# <li>
# <a href="https://www.idealista.it/sala-stampa/report-prezzo-immobile/" title="Report dei prezzi">
# Report dei prezzi
# </a>
# </li>
# <li>
# <a href="https://www.idealista.it/maps/" title="idealista maps">
# idealista maps
# </a>
# </li>
# <li>
# <a href="/luxury-homes-italy" title="Case di lusso in vendita in Italia">
# Case di lusso in vendita in Italia
# </a>
# </li>
# <li>
# <a href="/luxury-rentals-italy" title="Case di lusso in affitto in Italia">
# Case di lusso in affitto in Italia
# </a>
# </li>
# </ul>
# </nav>
# <nav>
# <h3>
# Hai un immobile?
# </h3>
# <ul>
# <li>
# <a href="/info/pubblica-annuncio" title="Inserisci annuncio gratis">
# Inserisci annuncio gratis
# </a>
# </li>
# <li>
# <a href="/privati" title="Prodotti per inserzionisti privati">
# Prodotti per inserzionisti privati
# </a>
# </li>
# <li>
# <a href="/info/migliorare-foto-video" title="Migliora le foto del tuo annuncio">
# Migliora le foto del tuo annuncio
# </a>
# </li>
# <li>
# <a href="/attestato-prestazione-energetica/" title="Richiedi l'attestato di prestazione energetica (APE)">
# Richiedi l'attestato di prestazione energetica (APE)
# </a>
# </li>
# <li>
# <a href="/contratti-di-affitto/" title="Crea gratuitamente il tuo contratto di affitto">
# Crea gratuitamente il tuo contratto di affitto
# </a>
# </li>
# <li>
# <a href="/valutazione-di-immobili/" title="Valuta gratis qualsiasi immobile">
# Valuta gratis qualsiasi immobile
# </a>
# </li>
# <li>
# <a href="/quale-agenzia-immobiliare-scegliere/" title="Vendi il tuo appartamento con un'agenzia">
# Vendi il tuo appartamento con un'agenzia
# </a>
# </li>
# <li>
# <a href="/come-vendere-casa/" title="Guida per vendere la tua casa">
# Guida per vendere la tua casa
# </a>
# </li>
# </ul>
# </nav>
# <nav>
# <h3>
# Sei un professionista immobiliare?
# </h3>
# <ul>
# <li>
# ...
#         </div>
#
#         <p>
#             Le banche di solito chiedono un contributo del <strong>{{=minLtvPercentage}}% del prezzo d'acquisto.</strong>
#         </p>
#
#         <a href="#" data-simulator-url="/mutui/hipoteca-para-comprar-casa?adId=23977397&xtatc=INT-8-[detalle_personalizar_hipoteca_consecutivo]" class="btn action expand go-to-simulator" target="_blank">
#             Calcola le spese
#         </a>
#
#         <div class="back-button-mortgages">
#             <a class="back-step1-btn" href="#">Torna indietro</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-validation-tmpl" type="text/microtemplate">
#
#
#
#     <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#         <p>Non è possibile trovare un mutuo con queste condizioni</p>
#     </div>
#
#     {{showAllErrors}}
#         <ul class="styled-list">
#             <li>
#                 Le banche non consentono che l'<strong>età</strong> del richiedente più giovane sia <strong> superiore ai 65 anni. </strong>
#             </li>
#             <li>
#                 Per questa casa e con il tuo capitale iniziale, dovresti pagare una rata mensile di <strong> {{=monthlyRate}}€ per 30 anni. </strong> Superato il 40% del tuo reddito, le banche non ti concederanno il mutuo.
#             </li>
#         </ul>
#     {{:showAllErrors}}
#         {{ageValid}}
#         {{:ageValid}}
#             <p>
#                 Le banche non consentono che l'<strong>età</strong> del richiedente più giovane sia <strong> superiore ai 65 anni. </strong>
#             </p>
#         {{/ageValid}}
#
#         {{debtRatioValid}}
#         {{:debtRatioValid}}
#             <p>
#                 Per questa casa e con il tuo capitale iniziale, dovresti pagare una rata mensile di <strong> {{=monthlyRate}}€ per 30 anni. </strong> Superato il 40% del tuo reddito, le banche non ti concederanno il mutuo.
#             </p>
#         {{/debtRatioValid}}
#     {{/showAllErrors}}
#
#     <div class="back-button-mortgages">
#         <a id="back-step2-btn" href="#">Torna indietro</a>
#     </div>
#
# </script>
# <script id="contact-mortgages-step2-low-income-validation-tmpl" type="text/microtemplate">
#
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>Non è possibile trovare un mutuo con queste condizioni</p>
#         </div>
#
#         <p>
#             Le banche con cui lavoriamo richiedono un <strong>reddito mensile minimo di 800€</strong> per concedere un mutuo.
#         </p>
#
#         <a href="#" data-simulator-url="" class="btn action expand go-to-simulator" target="_blank">
#             Calcola le spese
#         </a>
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Torna indietro</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-contract-type-validation-tmpl" type="text/microtemplate">
#
#         {{hasNoActivityContract}}
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>Non è possibile trovare un mutuo con queste condizioni</p>
#         </div>
#         {{/hasNoActivityContract}}
#
#         <p>
#             Le banche richiedono che almeno un candidato abbia <strong>stabilità del lavoro dimostrabile</strong> per concedere un mutuo.
#         </p>
#
#         {{hasTemporalContract}}
#         <button id="temporal-to-step3-btn" type="button" class="btn action expand">Continua</button>
#         {{/hasTemporalContract}}
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Torna indietro</a>
#         </div>
#
# </script>
# <script id="contact-mortgages-step2-country-validation-tmpl" type="text/microtemplate">
#
#         <div class="feedback contextual full-width warning icon-feedbk-alert error-container">
#             <p>Non è possibile trovare un mutuo con queste condizioni</p>
#         </div>
#         <p>
#
#
#
#             Non abbiamo prodotti per residenti in {{=countrySelected}}
#             <a href="{{=invalidCountryGuide}}" target="_blank">perchè?</a>
#         </p>
#
#         <div class="back-button-mortgages">
#             <a id="back-step2-btn" href="#">Torna indietro</a>
#         </div>
#
# </script>
# <script id="show-more-photos-tmpl" type="text/microtemplate">
#
# 		<div id="show-more-photos-button" class="button overlay-box">
# 			<a class="btn regular more-photos" data-markup="seePhotos">
# 				Visualizza {{=hiddenPhotosLeft}} foto seguenti
# 			</a>
# 		</div>
#
# </script>
# <script id="saving-alert-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
# {{lessSavingAlert}}
# 	Devi coprire la quota minima richiesta dalle banche. <a id="link-set-saving" href="" data-markup='detalle::mortgages::savings-adjust'>Calcola</a>.
# {{/lessSavingAlert}}
#
# {{bigSavingWarning}}
# 	Il capitale iniziale non può essere superiore al prezzo dell’immobile
# {{/bigSavingWarning}}
#
# </script>
# <script id="saving-warning-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Il capitale iniziale non può essere superiore al prezzo dell’immobile
#
# </script>
# <script id="minmortgages-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Le banche di solito non concedono un mutuo se l'importo del mutuo è inferiore a {{=minMortgages}}€
#
#     </div>
#
# </script>
# <script id="minhouseprice-alert-tmpl" type="text/microtemplate">
#
#     <div class="feedback contextual full-width neutral-temp icon-feedbk-info">
#
#
#
#
#
#
#
#
#
#
#
#
# Le banche di solito non concedono un mutuo per case il cui prezzo è inferiore a {{=minHousePrice}}€
#
#     </div>
# </script>
# <script id="expenses-glossary-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div id="expenses-glossary-content" class="expenses-glossary">
# 	<p class="h3-simulated txt-bold mb-regular">Imposte e spese</p>
# 	<p>Calcolo basato su posizione e condizione dell'immobile.</p>
# 	<table id="buying-expenses">
# 		<thead>
# 			<tr>
# 				<th class="txt-bold" colspan="3">Spese d’acquisto</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr>
# 				<td>Studio notarile: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.notaryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Registro: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.registryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Agenzia amministrativa: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.processAgencyExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Imposte: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.taxesExpenses.total}} &euro;</span></td>
# 			</tr>
# 			<tr class="total">
# 				<td class="result">Totale: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=buyingExpenses.total}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<table id="loan-expenses">
# 		<thead>
# 			<tr>
# 				<th class="txt-bold" colspan="3">Spese del mutuo</th>
# 			</tr>
# 		</thead>
# 		<tbody>
# 			<tr>
# 				<td>Studio notarile: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.notaryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Registro: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.registryExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Agenzia amministrativa: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.processAgencyExpenses}} &euro;</span></td>
# 			</tr>
# 			<tr>
# 				<td>Imposte: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.taxesExpenses.total}} &euro;</span></td>
# 			</tr>
# 			<tr class="total">
# 				<td class="result">Totale: </td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=loanExpenses.total}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<table id="results">
# 		<tbody>
# 			<tr class="total">
# 				<td><strong>Spese totali</strong></td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><strong>{{=totalExpenses}} &euro;</strong></td>
# 			</tr>
# 			<tr>
# 				<td>Spese di perizia</td>
# 				<td class="separator"><span></span></td>
# 				<td class="price"><span>{{=tasationExpenses}} &euro;</span></td>
# 			</tr>
# 		</tbody>
# 	</table>
#
# 	<p class="txt-result">Questo è un calcolo indicativo e non vincolante. Sarà necessario inviare le informazioni dettagliate alla banca per calcolare l’importo esatto.</p>
# </div>
#
# </script>
# <script id="rate-type-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<h3 class="txt-medium txt-bold mb-small">Come abbiamo calcolato il tasso di interesse?</h3>
# 	<p>Questo tasso di interesse è un riferimento medio del mercato dei mutui.</p>
# 	<p><strong>Fisso: </strong>tasso di interesse costante per tutta la durata per prestito. È più basso quando il termine è più breve.</p>
# 	<p><strong>Variabile: </strong>calcolato in base all'Euribor 3m + 0,90%.</p>
# </div>
#
# </script>
# <script id="savings-info-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="mortgages-modal-content-container">
# 	<p></p>
# </div>
#
# </script>
# <script data-title="" id="affida-contact-mortgages-tmpl" type="text/microtemplate">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <section class="affida-contact">
#     <div class="modal-inner">
#         <form id="send-contact-form" method="post" novalidate>
#
#             <div class="logo-idealista">
#                 <a href="/mutui/">
#
#
#
#                             <span class="icon-idealista-icon"></span>
#
#
#                     <span class="icon-hipotecas"></span>
#                 </a>
#             </div>
#             <div class="item-form affida-items">
#                 <div class="item-form">
#                     <label>
#                         <span>Prezzo immobile</span>
#                         <span class="desc-container">
#                             <span class="desc">Euro</span>
#                             <input type="tel" class="property-price" name="property-price" maxlength="9" data-min="0" data-max="2000000" data-validation="required number" data-message-required="Abbiamo bisogno di questo dato" value="{{=buyingPrice}}">
#                         </span>
#                     </label>
#                 </div>
#
#                 <div class="item-form">
#                     <label>
#                         <span class="show-mobile">Capitale iniziale</span>
#                         <span class="show-desktop">Capitale iniziale</span>
#                         <span class="desc-container">
#                             <span class="desc">Euro</span>
#                             <input type="tel" class="savings-input" name="savings" maxlength="9" data-min="0" data-max="2000000" data-validation="required number" data-message-required="Abbiamo bisogno di questo dato" value="{{=savings}}" />
#
#                         </span>
#                     </label>
#                 </div>
#                 <div class="item-form">
#                     <label>
#                         <span>Durata (anni)</span>
#                         <select class="duration-in-years" name="duration-in-years" data-validation="select" data-message-select="Abbiamo bisogno di questo dato">
#                             <option value="">Scegli</option>
#                             <option value="30" {{y30}} selected {{/y30}}>30</option>
#                             <option value="25" {{y25}} selected {{/y25}}>25</option>
#                             <option value="20" {{y20}} selected {{/y20}}>20</option>
#                             <option value="15" {{y15}} selected {{/y15}}>15</option>
#                             <option value="10" {{y10}} selected {{/y10}}>10</option>
#                         </select>
#                     </label>
#                 </div>
#                 <div class="item-form">
#                     <label>
#                         Tipo di interesse
#                         <ul class="horizontal-list">
#                             <li>
#                                 <label class="input-radio">
#                                     <input type="radio" name="tax-type" value="2" {{variableRate}} checked="checked" {{/variableRate}}>
#                                     <span>
# 										<span>Variabile</span>
# 									</span>
#                                 </label>
#                             </li>
#                             <li>
#                                 <label class="input-radio">
#                                     <input type="radio" name="tax-type" value="1" {{fixedRate}} checked="checked" {{/fixedRate}}>
#                                     <span>
# 										<span>Fisso</span>
# 									</span>
#                                 </label>
#                             </li>
#                         </ul>
#                     </label>
#                 </div>
#             </div>
#             <div class="affida-offer">
#                 <div class="affida-offer__main">
#                     <p class="txt-big">La nostra migliore offerta</p>
#                     <p class="txt-bold txt-big affida-offer__monthly"><span id="js-calculated-monthly">3901</span> €/mese</p>
#                 </div>
#                 <div class="affida-offer__details">
#                     <p>
#                         <span class="affida-offer__details__condition">Capitale iniziale:</span>
#                         <span><span id="js-calculated-savings"></span>€</span>
#                     </p>
#                     <p>
#                         <span class="affida-offer__details__condition">Importo mutuo:</span>
#                         <span><span id="js-calculated-loan"></span>€</span>
#                     </p>
#                     <p>
#                         <span class="affida-offer__details__condition">Interesse:</span>
#                         <span><span id="js-calculated-tax"></span>%</span>
#                     </p>
#                 </div>
#             </div>
#             <div id="minmortgages-alert-modal"></div>
#             <div class="affida-offer__btn-container">
#                 <a href="#" id="js-affida-form" class="btn action fullwidth send-form">Trova il tuo mutuo</a>
#             </div>
#         </form>
#         <div class="affida-legal">
#             <p>Affida S.r.l. : Il tipo di interesse indicato è il più vantaggioso disponibile tra gli istituti in convenzione con Affida S.r.l. ed è il risultato di un calcolo algoritmico di mutuo ipotecario. La rata è pubblicata a fini meramente informativi e potrà essere confermato o ricalcolato a seguito di consulenza ed analisi di Affida S.r.l. ed in funzione dei parametri di credito delle banche e/o di altri finanziatori. Mettiti in contatto con uno degli oltre 200 Personal Broker Affida presenti su tutto il territorio nazionale per ottenere una consulenza ed il coupon "La Casa in Tasca", un documento ufficiale rilasciato da un istituto finanziario partner di Affida S.r.l. che ti darà la certezza di ottenere il mutuo ipotecario alle condizioni stabilite. Fogli informativi a disposizione presso la rete agenziale Affida S.r.l o sul sito Affida.credit</p>
#         </div>
#     </div>
# </section>
#
#
# </script>
# <script id="comment-translation-tmpl" type="text/microtemplate">
#
#         <div class="translationWarning">
#             <span>{{=message}}</span>
#             <span class="viewOriginalComment"><a href="#" data-lang="it">{{=messageLink}}</a></span>
#             <div class="googleTranslateLogo"><img src="https://st1.idealista.it/static/common/release/detail/resources/img/google-translate.png"></div>
#         </div>
#
# </script>
# <script id="expander-button-tmpl" type="text/microtemplate">
#
#             <div class="expanderParent">
#                 <span class="icon-arrow-right"></span>
#                 <a href="#" class="expander">Leggi il commento completo</a>
#             </div>
#
# </script>
# </body>
# </html>

# %% [markdown]
# and this is pretty much the same html code you see on the right on a web page when you press `inspect`.
#
# From here is difficult to understand whats is going on, but on the web page using inspect you can see which part of the code is responsible of which part of the web page:
#
# for example the title of the ad is under `<span class='main-info__title-main'>`, so we can extract it using `.find()`:

# %%
title = soup.find('span', class_='main-info__title-main')
title = title.get_text()
print(title)
# Out:
# Appartamento su due piani in vendita in via Evangelista Torricelli, 20

# %% [markdown]
# and in this way we can extract everything: `title`, `place`, `size`, `price` and the link

# %%
scrape_page(url)
# Out:
# https://www.idealista.it/immobile/23977397/
# Appartamento su due piani in vendita in via Evangelista Torricelli, 20
# Navigli-Porta Genova, Milano
# 620.000 €
# 110 m^2
